# %% [markdown]
# <a href="https://colab.research.google.com/github/AM0ya/Clase_Programacion/blob/main/Primer_Ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **HOLA ESTO ES UN EJEMPLO**

# %%
print("Hola a todos")
# Out:
# Hola a todos
